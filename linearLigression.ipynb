# %%
#linearLigression is used for continous values datasets
#folmula of a linearLigression
## y = mx + c
#y = b0 + b1*c

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/project_1_dataset.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = data[["YearsExperience"]]

# %%
y = data["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
lr.intercept_
# Out:
# 26657.34946418499

# %%
lr.coef_
# Out:
# array([9538.12333145])

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([124900.01977815, 112500.45944726,  64809.84279   ,  69578.90445572,
#         47641.22079338,  54317.9071254 , 126807.64444444,  57179.34412484])

# %%
y_test
# Out:
# 28    122391.0
# 25    105582.0
# 11     55794.0
# 14     61111.0
# 4      39891.0
# 5      56642.0
# 29    121872.0
# 7      54445.0
# Name: Salary, dtype: float64

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 5581.941088550481

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 38056955.29584943

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X_test,y_test,'rx')
plt.plot(X_test,y_pred,c = 'black')
