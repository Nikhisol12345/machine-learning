# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Market_Basket_Optimisation.csv')

# %%
data.shape
# Out:
# (7500, 20)

# %%
transation = []

# %%
for i in range(0,7501):
  transation.append([str(data.values[i,j])for j in range(0,20)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-712c5599ce43> in <module>()
#       1 for i in range(0,7501):
# ----> 2   transation.append([str(data.values[i,j])for j in range(0,20)])
#
# <ipython-input-12-712c5599ce43> in <listcomp>(.0)
#       1 for i in range(0,7501):
# ----> 2   transation.append([str(data.values[i,j])for j in range(0,20)])
#
# IndexError: index 7500 is out of bounds for axis 0 with size 7500
