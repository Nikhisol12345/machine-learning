# %%
import pandas as pd

# %%
# !unzip -u "/content/train.zip" -d "/content/train"
# Out:
# Archive:  /content/train.zip
#   inflating: /content/train/Image_002039.jpg
#   inflating: /content/train/Image_002040.jpg
#   inflating: /content/train/Image_002041.jpg
#   inflating: /content/train/Image_002042.jpg
#   inflating: /content/train/Image_002043.jpg
#   inflating: /content/train/Image_002044.jpg
#   inflating: /content/train/Image_002045.jpg
#   inflating: /content/train/Image_002046.jpg
#   inflating: /content/train/Image_002047.jpg
#   inflating: /content/train/Image_005671.jpg
#   inflating: /content/train/Image_005672.jpg
#   inflating: /content/train/Image_005673.jpg
#   inflating: /content/train/Image_005674.jpg
#   inflating: /content/train/Image_005675.jpg
#   inflating: /content/train/Image_005676.jpg
#   inflating: /content/train/Image_005677.jpg
#   inflating: /content/train/Image_005678.jpg
#   inflating: /content/train/Image_005679.jpg
#   inflating: /content/train/Image_005680.jpg
#   inflating: /content/train/Image_007811.jpg
# ...
