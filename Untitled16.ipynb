# %%
import pandas as pd
import requests

# %%
url = "https://coronavirus-smartable.p.rapidapi.com/news/v1/US/"

headers = {
	"X-RapidAPI-Key": "44825bca73mshe54f89e2d2405c0p1e8997jsn743dcb2e31bb",
	"X-RapidAPI-Host": "coronavirus-smartable.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

# %%
val= response.json()['location']

# %%
val['countryOrRegion']
# Out:
# 'United States'

# %%
df = pd.DataFrame(val.items())

# %%
df2 = df.rename(row =df.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-2c07f5b771fe> in <module>()
# ----> 1 df2 = df.rename(row =df.iloc[0])
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# TypeError: rename() got an unexpected keyword argument 'row'

# %%
df2
# Out:
#               long     -95.712891
# 0             long     -95.712891
# 1  countryOrRegion  United States
# 2  provinceOrState           None
# 3           county           None
# 4          isoCode             US
# 5              lat       37.09024

# %%
for i in range(10):
  player_data = response.json()[i]
  values = player_data.values()
  temp = pd.DataFrame(list(values))
  df = df.append(temp,ignore_index=True)
