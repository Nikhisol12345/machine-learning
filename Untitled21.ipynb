# %%
print("Data","Science", "Mentorship", "Program" 
,"By", "CampusX" ,sep= '-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %%
# Write your code here
frist = int(input())
second = int(input())

temp = frist
frist = second
second = temp
print("this is frist :", frist)
print("this is second :" ,second)
# Out:
# 3
# 4
# this is frist : 4
# this is second : 3

# %%
import numpy as np

x1 = int(input())
x2 = int(input())
x3 = int(input())
y1 = int(input())
y2 = int(input())
y3 = int(input())
point1 = np.array((x1,x2,x3))
point2 = np.array((y1,y2,y3))

sum = point1 - point2
sum_sq = np.dot(sum.T,sum)
print(np.sqrt(sum_sq))
# Out:
# 1
# 2
# 3
# 1
# 1
# 1
# 2.23606797749979

# %%
cuur_pop = 10000
for i in range(10,0,-1):
  
  print(i,cuur_pop)
  cuur_pop = cuur_pop/1.1
# Out:
# 10 10000
# 9 9090.90909090909
# 8 8264.462809917353
# 7 7513.148009015775
# 6 6830.134553650703
# 5 6209.213230591548
# 4 5644.739300537771
# 3 5131.5811823070635
# 2 4665.07380209733
# 1 4240.976183724845
