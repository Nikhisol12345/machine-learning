# %% [markdown]
# **Import Library Required:**

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import numpy as np

# %%
weppage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
soup = BeautifulSoup(weppage,'lxml')

# %%
soup.find_all('h1')[0].text
# Out:
# 'List of companies in India'

# %%
company = soup.find_all('div',class_ ='company-content-wrapper')
other = company[0].find_all('p', class_ = 'infoEntity')

# %%
company_name = []
rating = []
review = []
com_type =[]
location = []
old = []
employees = []
for i in company:
  company_name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  review.append(i.find('a', class_ = 'review-count').text.strip())
  com_type.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  location.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df = pd.DataFrame({'company_name':company_name ,'rating':rating,'review':review,'com_type':com_type,'location':location,'old':old,'employees':employees})

# %%
final_dataset = pd.DataFrame()
for j in range(1,30):
  weppage = requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
  soup = BeautifulSoup(weppage,'lxml')
  company = soup.find_all('div',class_ ='company-content-wrapper')
  company_name = []
  rating = []
  review = []
  com_type =[]
  location = []
  old = []
  employees = []
  for i in company:
    try:
      company_name.append(i.find('h2').text.strip())

    except:
      company_name.append(np.nan)  

    try:
      rating.append(i.find('p',class_='rating').text.strip())

    except:
      rating.append(np.nan)  
    try:
      review.append(i.find('a', class_ = 'review-count').text.strip())

    except:
      review.append(np.nan)  
    try:
      com_type.append(i.find_all('p',class_='infoEntity')[0].text.strip())

    except:
      com_type.append(np.nan)  
    try:
      location.append(i.find_all('p',class_='infoEntity')[1].text.strip())

    except:
      location.append(np.nan)  
    try:
      old.append(i.find_all('p',class_='infoEntity')[2].text.strip())

    except:
      old.append(np.nan)  
    try:
      employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())

    except:
      employees.append(np.nan)  

  df = pd.DataFrame({'company_name':company_name ,'rating':rating,'review':review,'com_type':com_type,'location':location,'old':old,'employees':employees})

  final_dataset = final_dataset.append(df,ignore_index=True)

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  869 non-null    object
#  1   rating        869 non-null    object
#  2   review        869 non-null    object
#  3   com_type      869 non-null    object
#  4   location      869 non-null    object
#  5   old           863 non-null    object
#  6   employees     840 non-null    object
# dtypes: object(7)
# memory usage: 47.6+ KB

# %%
final_dataset.to_csv()
# Out:
# ',company_name,rating,review,com_type,location,old,employees\n0,TCS,3.9,(45.1k Reviews),Public,"Mumbai,Maharashtra + 253 more",54 years old,1 Lakh+ Employees (India)\n1,Accenture,4.2,(29.6k Reviews),Public,"Dublin,Dublin + 137 more",33 years old,1 Lakh+ Employees (India)\n2,Cognizant,4.0,(26.8k Reviews),Private,Teaneck. New Jersey. + 88 more,28 years old,1 Lakh+ Employees (India)\n3,ICICI Bank,4.0,(33.4k Reviews),Public,"Mumbai,Maharashtra + 1018 more",28 years old,50k-1 Lakh Employees (India)\n4,Wipro,3.9,(25.2k Reviews),Public,"Bangalore/Bengaluru,Karnataka + 261 more",77 years old,1 Lakh+ Employees (India)\n5,HDFC Bank,4.0,(34.9k Reviews),Public,"Mumbai,Maharashtra + 1152 more",28 years old,1 Lakh+ Employees (India)\n6,Capgemini,3.9,(21.8k Reviews),Public,Paris + 75 more,55 years old,1 Lakh+ Employees (India)\n7,HCL Technologies,3.9,(21.4k Reviews),Public,"Noida,Uttar Pradesh + 162 more",46 years old,1 Lakh+ Employees (India)\n8,Infosys,4.0,(25.5k Reviews),Public,"Bengaluru/Bangal
# ...
