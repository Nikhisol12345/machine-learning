# %%
import pandas as pd
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
n_samples,n_future = 10,5

# %%
r = np.random.RandomState(0)

# %%
r
# Out:
# RandomState(MT19937) at 0x7F362768F380

# %%
y = r.randn(n_samples)

# %%
x = r.randn(n_samples,n_future)

# %%
model = make_pipeline(StandardScaler(),SVR())

# %%
model.fit(x,y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svr', SVR())])

# %%
y_pred = model.predict(x)

# %%
y_pred
# Out:
# array([ 0.80185075,  0.50050052,  0.93341268,  1.67234653,  0.89082705,
#         0.28538774,  0.8504317 , -0.05156277,  0.3322631 ,  0.31011751])

# %%
y
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ])
