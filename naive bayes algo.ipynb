# %% [markdown]
# naive bayes algo
# its work on bayes'theorem
# bayes work in probablity
# folmula of conditional probablity
# p(A|B) = p(A and B)/p(A)

# %%
#naive bayes algo
#its work on bayes'theorem
#naive bayes work in probablity
#folmula of conditional probablity
#p(A|B) = p(A and B)/p(A) ,
#Bayes theorem 
#the formula is :p(A|B) =p(B|A).P(A)/P(A)
